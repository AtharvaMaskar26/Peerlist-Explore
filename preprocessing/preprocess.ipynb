# %%
import json

# %%
database = []
with open("../scraping/data.json", "r") as json_file:
    database = json.load(json_file)

# %%
import pandas as pd

# %%
dataframe = pd.DataFrame(database)

dataframe
# Out:
#                                                   link  monthly_rank  \
# 0       https://peerlist.io/codersalman/project/scattr             1
# 1    https://peerlist.io/narottam/project/signlanguage             2
# 2    https://peerlist.io/bionic/project/declutr--so...             3
# 3      https://peerlist.io/manuarora/project/algochurn             4
# 4    https://peerlist.io/rutikwankhade/project/tabwave             5
# ..                                                 ...           ...
# 947  https://peerlist.io/rahulsingh_ca/project/svel...           123
# 948      https://peerlist.io/architr/project/atlabs-ai           124
# 949      https://peerlist.io/kadirhan/project/hepltech           125
# 950  https://peerlist.io/amarjeetpatidar/project/fi...           126
# 951         https://peerlist.io/bastien/project/owlbot           127
#
#                                    project_name  \
# 0                                        Scattr
# ...

# %%
print((dataframe == "").sum())
# Out:
# link                    0
# monthly_rank            0
# project_name            0
# project_subheading      0
# description           146
# month                   0
# year                    0
# number_of_upvotes       0
# dtype: int64

# %%
dataframe = dataframe[dataframe['description'] != ""]

# %%
dataframe
# Out:
#                                                   link  monthly_rank  \
# 0       https://peerlist.io/codersalman/project/scattr             1
# 1    https://peerlist.io/narottam/project/signlanguage             2
# 2    https://peerlist.io/bionic/project/declutr--so...             3
# 3      https://peerlist.io/manuarora/project/algochurn             4
# 4    https://peerlist.io/rutikwankhade/project/tabwave             5
# ..                                                 ...           ...
# 947  https://peerlist.io/rahulsingh_ca/project/svel...           123
# 948      https://peerlist.io/architr/project/atlabs-ai           124
# 949      https://peerlist.io/kadirhan/project/hepltech           125
# 950  https://peerlist.io/amarjeetpatidar/project/fi...           126
# 951         https://peerlist.io/bastien/project/owlbot           127
#
#                                    project_name  \
# 0                                        Scattr
# ...

# %%
print((dataframe == "").sum())
# Out:
# link                  0
# monthly_rank          0
# project_name          0
# project_subheading    0
# description           0
# month                 0
# year                  0
# number_of_upvotes     0
# dtype: int64

# %%
dataframe.shape
# Out:
# (806, 8)

# %%
print(dataframe.dtypes)

dataframe['year']

# dataframe = dataframe.rename(columns={'year': 'months'})
# dataframe = dataframe.rename(columns={'month': 'year'})
# Out:
# link                  object
# monthly_rank           int64
# project_name          object
# project_subheading    object
# description           object
# month                 object
# year                  object
# number_of_upvotes     object
# dtype: object
# 0      Mar
# 1      Mar
# 2      Mar
# 3      Mar
# 4      Mar
#       ...
# 947    May
# 948    May
# 949    May
# 950    May
# 951    May
# Name: year, Length: 806, dtype: object

# %%
# dataframe['months']
dataframe.columns
# Out:
# Index(['link', 'monthly_rank', 'project_name', 'project_subheading',
#        'description', 'month', 'year', 'number_of_upvotes'],
#       dtype='object')

# %%
dataframe.columns = ['link', 'monthly_rank', 'project_name', 'project_subheading',
       'description', 'year', 'month', 'number_of_upvotes']

# %%
dataframe.dtypes
# Out:
# link                  object
# monthly_rank           int64
# project_name          object
# project_subheading    object
# description           object
# year                  object
# month                 object
# number_of_upvotes     object
# dtype: object

# %%
dataframe['year'] = dataframe['year'].astype(int)
# Out:
# C:\Users\athar\AppData\Local\Temp\ipykernel_15176\3169853501.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['year'] = dataframe['year'].astype(int)

# %%
dataframe['number_of_upvotes'] = dataframe['number_of_upvotes'].astype(int)
# Out:
# C:\Users\athar\AppData\Local\Temp\ipykernel_15176\3002922701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['number_of_upvotes'] = dataframe['number_of_upvotes'].astype(int)

# %%
dataframe.dtypes
# Out:
# link                  object
# monthly_rank           int64
# project_name          object
# project_subheading    object
# description           object
# year                   int32
# month                 object
# number_of_upvotes      int32
# dtype: object

# %%
import pandas as pd
from sqlalchemy import create_engine
import os 
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
SQL_URL = os.getenv('MYSQL_URL')
engine = create_engine(SQL_URL)

# %%
# Define the name of the table where you want to insert the data
table_name = 'Projects'

# Insert data into the SQL table
dataframe.to_sql(table_name, con=engine, if_exists='append', index=False)

print("Data inserted successfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\athar\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\athar\anaconda3\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:170, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     169 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 170     rowcount = cursor.executemany(statement, parameters)
#     171     if context is not None:
#
# ...

# %%
json_list = json.loads(json.dumps(list(dataframe.T.to_dict().values())))

# %%
json_list
# Out:
# [{'link': 'https://peerlist.io/codersalman/project/scattr',
#   'monthly_rank': 1,
#   'project_name': 'Scattr',
#   'project_subheading': 'The Easiest Way to Spread Your Writing Across the Internet  | Cross-posting tool',
# ...

# %%
# Write the data to a JSON file
with open('data.json', 'w') as f:
    json.dump(json_list, f, indent=4)
